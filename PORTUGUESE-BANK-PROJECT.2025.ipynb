# %% [markdown]
# # ***Portuguese Bank Project***

# %% [markdown]
# ### ***Task 1:-Prepare a complete data analysis report on the given data.***

# %% [markdown]
# **Dataset and libraries importation**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv('bank-additional-full.csv', sep=';')
print(data.head())
print(data.info())
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
data.replace('unknown', pd.NA, inplace=True)
data.dropna(inplace=True)

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  30488.000000  30488.000000  30488.000000  30488.000000  30488.000000
# mean      39.030012    259.484092      2.521451    956.332295      0.194273
# std       10.333529    261.714262      2.720150    201.373292      0.522788
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       31.000000    103.000000      1.000000    999.000000      0.000000
# 50%       37.000000    181.000000      2.000000    999.000000      0.000000
# 75%       45.000000    321.000000      3.000000    999.000000      0.000000
# max       95.000000   4918.000000     43.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  30488.000000    30488.000000   30488.000000  30488.000000  30488.000000
# mean      -0.071510       93.523311     -40.602263      3.459938   5160.813409
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 10

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
#fetching the Categorical columns
cat_data=data.select_dtypes(include='object')
cat_data.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
#fetching the Numerical columns
num_data=data.select_dtypes(include=['int64','float64'])
num_data.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Univariate Analysis**

# %%
#Check for Unique Values
for i in cat_data:
    print(i,data[i].unique())
    print(data[i].value_counts())
    print("*******")
    print('  ')
# Out:
# job ['housemaid' 'services' 'admin.' 'technician' 'blue-collar' 'unemployed'
#  'retired' 'entrepreneur' 'management' 'student' 'self-employed']
# admin.           8737
# blue-collar      5675
# technician       5473
# services         2857
# management       2311
# retired          1216
# self-employed    1092
# entrepreneur     1089
# unemployed        738
# housemaid         690
# student           610
# Name: job, dtype: int64
# *******
#
# marital ['married' 'single' 'divorced']
# married     17492
# single       9443
# divorced     3553
# Name: marital, dtype: int64
# *******
#
# education ['basic.4y' 'high.school' 'basic.6y' 'professional.course' 'basic.9y'
#  'university.degree' 'illiterate']
# university.degree      10412
# high.school             7699
# professional.course     4321
# basic.9y                4276
# basic.4y                2380
# basic.6y                1389
# illiterate                11
# Name: education, dtype: int64
# *******
#
# default ['no' 'yes']
# ...

# %%
#Catgorical Data
#Barplot
# Define a color palette
palette = sns.color_palette("Set2")

# Adjust figure dimensions for clarity
plt.figure(figsize=(20, 25), facecolor='white')

# Generate barplots for categorical data
for i, column in enumerate(cat_data.columns, start=1):
    ax = plt.subplot(4, 3, i)
    order = cat_data[column].value_counts().index
    sns.barplot(y=cat_data[column].value_counts().values, 
                x=order, 
                palette=palette)  # Applying color palette to each plot
    
    # Set labels and titles
    plt.ylabel("Count", fontsize=16)
    plt.xlabel(column, fontsize=16)
    plt.xticks(rotation=90, fontsize=12)
    plt.title(f"Barplot of {column}", fontsize=18)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Jobs: "Admin" is the most common job (10,422), followed by "Blue-collar" (9,254) and "Technician" (6,743). "Students" are the least represented (875).
#
# Marital: "Married" dominates (24,928), followed by "Single" (11,568) and "Divorced" (4,612).
#
# Education: "University Degree" is most common (12,168), while "Illiterate" and "Unknown" are rare.
#
# Default: Majority have no credit default (32,588); 8,597 have "Unknown" status.
#
# Housing: 21,576 have housing loans, while 18,622 do not. 990 are "Unknown."
#
# Loan: Most customers (33,950) do not have personal loans, while 6,248 do. 990 are "Unknown."
#
# Contact: "Cellular" is preferred (26,144), followed by "Telephone" (15,044).
#
# Month: "May" is the busiest (13,769), and "December" is the least active (182).
#
# Day of Week: "Thursday" is the busiest day (8,623), and "Friday" is the least busy (7,827).
#
# Poutcome: "Nonexistent" dominates (35,563), followed by "Failure" (4,252), and "Success" (1,373).
#
# Target (y): Most customers did not subscribe (36,548), while 4,640 subscribed.

# %%
# numerical data
# Histogram plot for numerical features
plt.figure(figsize=(18, 22), facecolor='white')  # Adjust figure size for better visibility
plotnumber = 1

for i, column in enumerate(num_data.columns, 1):  # Using enumerate for cleaner iteration
    ax = plt.subplot(4, 3, i)
    
    # Improved histogram with KDE and color adjustments
    sns.histplot(data[column], kde=True, bins=30, color='royalblue', edgecolor='black', alpha=0.7)

    plt.xlabel(column, fontsize=14, fontweight='bold')
    plt.ylabel('Count', fontsize=14, fontweight='bold')
    plt.title(f"Distribution of {column}", fontsize=16)
    
    plotnumber += 1

plt.suptitle("Numerical Features Distribution", fontsize=20, y=1.02)  # Overall title
plt.tight_layout()
plt.show()

# %% [markdown]
# The features 'age,' 'duration,' 'campaign,' 'pdays,' 'previous,' 'emp.var.rate,' 'cons.price.idx,' 'cons.conf.idx,' 'euribor3m,' and 'nr.employed' are all continuous numerical variables.
#
# These numerical features exhibit irregular patterns and do not follow a standard normal distribution, showing peaks, valleys, and deviations.
#
# The 'pdays' feature is heavily right-skewed, with the most common value being 999, occurring 39,673 times. It also has a long tail of less frequent values, including some potential outliers.
#
# The 'previous' feature has a highly imbalanced distribution: the majority of values are 0 (35,563 instances), while the remaining values (1, 2, 3, 4, 5, 6, 7) are much less frequent, highlighting a class imbalance issue.

# %%
# Boxplot for numerical features with improved styling
plt.figure(figsize=(18, 22), facecolor='white')  # Adjusted size for better layout
plotnumber = 1

for i, column in enumerate(num_data.columns, 1):  # Using enumerate for better readability
    ax = plt.subplot(4, 3, i)
    
    # Boxplot with enhanced visual properties
    sns.boxplot(x=data[column], color='skyblue', showfliers=True, notch=True, 
                boxprops={'edgecolor': 'black'}, flierprops={'markerfacecolor': 'red', 'marker': 'o'})

    plt.xlabel(column, fontsize=14, fontweight='bold')
    plt.ylabel('Value', fontsize=14, fontweight='bold')
    plt.title(f"Boxplot of {column}", fontsize=16)
    
    plt.grid(axis='x', linestyle='--', alpha=0.6)  # Add grid lines for readability
    
    plotnumber += 1

plt.suptitle("Numerical Features Boxplots", fontsize=20, fontweight='bold', y=1.02)  # Add overall title
plt.tight_layout()
plt.show()

# %% [markdown]
# Box plots for the numerical columns 'age,' 'duration,' 'campaign,' 'previous,' and 'cons.conf.idx' revealed the presence of outliers.
#
# 'Age' outliers may represent extreme values, potentially indicating clients at the very high or low ends of the age spectrum.
# 'Duration' outliers might correspond to unusually long or short contact durations during campaigns.
#
# Outliers in 'Campaign' could highlight clients contacted an exceptionally high number of times.
#
# Outliers in 'cons.price.idx' and 'cons.conf.idx' suggest uncommon values in consumer price index or consumer confidence levels.
#
# No significant outliers were observed in the columns 'pdays,' 'emp.var.rate,' 'euribor3m,' and 'nr.employed,' indicating relatively consistent distributions in these variables.

# %% [markdown]
# ## **Bivariate Analysis**

# %%
if 'y' in cat_data.columns:
    cat_data.drop('y', axis=1, inplace=True)

# %%
#Count plot
# Create a new custom color palette with blues and greens
custom_palette = ["#3498DB", "#2ECC71", "#1ABC9C"]  # Blue, Green, Teal

# Set up the figure with appropriate number of rows and columns
fig, axes = plt.subplots(5, 2, figsize=(20, 25), facecolor='white')
axes = axes.flatten()  # Flatten to make iteration easier

# Loop through each categorical column and create count plots
for plotnumber, column in enumerate(cat_data.columns):
    ax = axes[plotnumber]
    sns.countplot(x=cat_data[column], hue=data['y'], ax=ax, palette=custom_palette)
    
    # Annotate each bar with its corresponding count value, handling NaNs safely
    for p in ax.patches:
        height = p.get_height()
        if not np.isnan(height):  # Check if height is not NaN
            ax.annotate(f'{int(height)}', 
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=12, color='black', 
                        xytext=(0, 5), textcoords='offset points')
        else:
            ax.annotate('N/A', 
                        (p.get_x() + p.get_width() / 2., 0),
                        ha='center', va='bottom', fontsize=12, color='red', 
                        xytext=(0, 5), textcoords='offset points')

    # Set axis labels and improve readability
    ax.set_xlabel(column, fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.set_title(f'Distribution of {column}', fontsize=18)
    ax.tick_params(axis='x', rotation=45)

# Remove empty subplots if cat_data has fewer than expected columns
if len(cat_data.columns) < len(axes):
    for i in range(len(cat_data.columns), len(axes)):
        fig.delaxes(axes[i])

# Adjust layout to prevent overlap and optimize spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# From above count plot analysis highlights clear trends in customer behavior, segmented by jobs, marital status, education, loans, contact methods, and previous outcomes. Insights from these patterns can guide targeted marketing strategies, such as focusing on higher-education customers, leveraging cellular contact methods, and improving engagement during active months like May. Addressing imbalances in certain groups (e.g., "Unknown" statuses) and analyzing patterns across occupations can further refine strategies for improved results.

# %%
# Histogram plot for numerical features
plt.figure(figsize=(18, 22), facecolor='white')  # Adjust figure size for better visibility
plotnumber = 1

for i, column in enumerate(num_data.columns, 1):  # Using enumerate for cleaner iteration
    ax = plt.subplot(4, 3, i)
    
    # Improved histogram with KDE and color adjustments
    sns.histplot(data[column], kde=True, bins=30, color='royalblue', edgecolor='black', alpha=0.7)

    plt.xlabel(column, fontsize=14, fontweight='bold')
    plt.ylabel('Count', fontsize=14, fontweight='bold')
    plt.title(f"Distribution of {column}", fontsize=16)
    
    plotnumber += 1

plt.suptitle("Numerical Features Distribution", fontsize=20, y=1.02)  # Overall title
plt.tight_layout()
plt.show()

# %% [markdown]
# The histograms reveal clear differences in the distributions between the 'Yes' and 'No' groups for key numerical columns. Features like 'age', 'duration', and 'campaign' show distinct patterns, with the 'Yes' group often having more defined peaks and tighter ranges, indicating higher relevance to the target outcome. Skewed distributions in columns like 'pdays' and 'previous' suggest specific ranges associated with the 'Yes' group. These insights highlight the importance of focusing on features with the greatest separation and addressing skewness or outliers to improve model performance.

# %%
# Define a new color palette for better visualization
custom_palette = sns.color_palette("coolwarm", as_cmap=True)

# Set up the figure
plt.figure(figsize=(20, 25), facecolor='white')
plotnumber = 1

# Iterate through numerical columns and create violin plots
for column in num_data:
    ax = plt.subplot(4, 3, plotnumber)
    
    # Violin plot with custom color palette
    sns.violinplot(x=data[column], y=data['y'], palette="coolwarm", ax=ax)

    # Set axis labels and improve readability
    plt.xlabel(column, fontsize=16)
    plt.ylabel('y', fontsize=16)
    plt.title(f'Distribution of {column}', fontsize=18)

    plotnumber += 1

# Adjust layout to prevent overlap and optimize spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# These violin plots illustrate the distribution of the numerical column for the 'Yes' and 'No' target values, providing a clear and comparative visualization of their respective patterns and variations.

# %% [markdown]
# ## **Mutlivariate Analysis**

# %%
#pairplot
sns.pairplot(data,hue='y')

plt.suptitle("Numerical Feature Pairplot", fontsize=28, fontweight='bold', y=1.02, color="#1c545c")
plt.show()

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#check for duplicate
data.duplicated().sum()
# Out:
# 10

# %%
data.loc[data.duplicated()]
# Out:
#        age          job   marital            education default housing loan  \
# 1266    39  blue-collar   married             basic.6y      no      no   no
# 14234   27   technician    single  professional.course      no      no   no
# 16956   47   technician  divorced          high.school      no     yes   no
# 18465   32   technician    single  professional.course      no     yes   no
# 20534   41   technician   married  professional.course      no     yes   no
# 25217   39       admin.   married    university.degree      no      no   no
# 28477   24     services    single          high.school      no     yes   no
# 32516   35       admin.   married    university.degree      no     yes   no
# 36951   45       admin.   married    university.degree      no      no   no
# 38281   71      retired    single    university.degree      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
data.drop(data[data.duplicated()].index, inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Boxplot for numerical features with improved styling
plt.figure(figsize=(18, 22), facecolor='white')  # Adjusted size for better layout
plotnumber = 1

for i, column in enumerate(num_data.columns, 1):  # Using enumerate for better readability
    ax = plt.subplot(4, 3, i)
    
    # Boxplot with enhanced visual properties
    sns.boxplot(x=data[column], color='skyblue', showfliers=True, notch=True, 
                boxprops={'edgecolor': 'black'}, flierprops={'markerfacecolor': 'red', 'marker': 'o'})

    plt.xlabel(column, fontsize=14, fontweight='bold')
    plt.ylabel('Value', fontsize=14, fontweight='bold')
    plt.title(f"Boxplot of {column}", fontsize=16)
    
    plt.grid(axis='x', linestyle='--', alpha=0.6)  # Add grid lines for readability
    
    plotnumber += 1

plt.suptitle("Numerical Features Boxplots", fontsize=20, fontweight='bold', y=1.02)  # Add overall title
plt.tight_layout()
plt.show()

# %%
# Finding Outlier in Age
Q1=data['age'].quantile(0.25)
print('lower quantile :',Q1)
Q3=data['age'].quantile(0.75)
print('upper quantile :',Q3)
# finding IQR
IQR=Q3-Q1
print('IQR :',IQR)
#finding lower and upper limit
lower_limit=Q1-1.5*IQR
print('lower_limit :',lower_limit)
upper_limit=Q3+1.5*IQR
print('upper_limit :',upper_limit)
# Out:
# lower quantile : 31.0
# upper quantile : 45.0
# IQR : 14.0
# lower_limit : 10.0
# upper_limit : 66.0

# %%
# find the values of above upper limit
data.loc[data.age>upper_limit]
# Out:
#        age        job   marital            education default housing loan  \
# 27713   70    retired  divorced             basic.4y      no     yes   no
# 27757   76    retired   married    university.degree      no      no  yes
# 27774   67    retired    single    university.degree      no     yes  yes
# 27780   73    retired   married    university.degree      no     yes   no
# 27800   88    retired  divorced             basic.4y      no     yes   no
# ...    ...        ...       ...                  ...     ...     ...  ...
# 40996   81    retired   married             basic.4y      no     yes   no
# 41004   80    retired   married  professional.course      no     yes   no
# 41153   67  housemaid  divorced  professional.course      no     yes   no
# 41183   73    retired   married  professional.course      no     yes   no
# 41187   74    retired   married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
#find the vales below lower limit
data.loc[data.age<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking the percentage of outlier
(len(data.loc[data.age>upper_limit])/len(data))
# Out:
# 0.014994422206181508

# %%
#check age median
data.age.median()
# Out:
# 37.0

# %%
# replace the outlier with median
data.loc[data['age']>upper_limit,'age']=data['age'].median()

# %%
#boxplot
sns.boxplot(x=data.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Checking the percentage of outlier
len(data.loc[data.age<lower_limit])/len(data)
# Out:
# 0.0

# %% [markdown]
# #. Duration

# %%
# Finding Outlier in duration
Q1=data['duration'].quantile(0.25)
print('lower quantile :',Q1)
Q3=data['duration'].quantile(0.75)
print('upper quantile :',Q3)
# finding IQR
IQR=Q3-Q1
print('IQR :',IQR)
#finding lower and upper limit
lower_limit=Q1-1.5*IQR
print('lower_limit :',lower_limit)
upper_limit=Q3+1.5*IQR
print('upper_limit :',upper_limit)
# Out:
# lower quantile : 103.0
# upper quantile : 321.0
# IQR : 218.0
# lower_limit : -224.0
# upper_limit : 648.0

# %%
# find the values of above upper limit
data.loc[data.duration>upper_limit]
# Out:
#        age          job   marital            education default housing loan  \
# 37      52   technician   married             basic.9y      no     yes   no
# 61      51  blue-collar   married             basic.9y      no     yes   no
# 88      49   technician   married             basic.9y      no      no   no
# 169     54   management  divorced    university.degree      no     yes   no
# 182     42  blue-collar   married             basic.9y      no     yes  yes
# ...    ...          ...       ...                  ...     ...     ...  ...
# 41147   25   technician    single  professional.course      no     yes   no
# 41153   37    housemaid  divorced  professional.course      no     yes   no
# 41160   33       admin.   married    university.degree      no      no   no
# 41164   54       admin.   married  professional.course      no      no   no
# 41166   32       admin.   married    university.degree      no      no   no
#
# ...

# %%
#find the vales below lower limit
data.loc[data.duration<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking the percentage of outlier
len(data.loc[data.duration>upper_limit])/len(data)
# Out:
# 0.07133013977295098

# %% [markdown]
# ### *Campaign*

# %%
# Finding Outlier in campaign
Q1=data['campaign'].quantile(0.25)
print('lower quantile :',Q1)
Q3=data['campaign'].quantile(0.75)
print('upper quantile :',Q3)
# finding IQR
IQR=Q3-Q1
print('IQR :',IQR)
#finding lower and upper limit
lower_limit=Q1-1.5*IQR
print('lower_limit :',lower_limit)
upper_limit=Q3+1.5*IQR
print('upper_limit :',upper_limit)
# Out:
# lower quantile : 1.0
# upper quantile : 3.0
# IQR : 2.0
# lower_limit : -2.0
# upper_limit : 6.0

# %%
# find the values of above upper limit
data.loc[data.campaign>upper_limit]
# Out:
#        age           job   marital            education default housing loan  \
# 887     54        admin.   married    university.degree      no      no   no
# 1094    40    technician   married  professional.course      no     yes   no
# 1230    48   blue-collar  divorced             basic.4y      no      no   no
# 1429    53        admin.   married    university.degree      no      no   no
# 1451    31   blue-collar  divorced             basic.4y      no     yes   no
# ...    ...           ...       ...                  ...     ...     ...  ...
# 40611   37       retired   married             basic.9y      no      no   no
# 40631   37       retired   married             basic.4y      no     yes   no
# 40698   29    technician    single  professional.course      no     yes   no
# 40821   33    technician    single  professional.course      no     yes   no
# 40993   50  entrepreneur  divorced    university.degree      no     yes   no
#
# ...

# %%
#find the vales below lower limit
data.loc[data.campaign<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking the percentage of outlier
(len(data.loc[data.campaign>upper_limit])/len(data))
# Out:
# 0.05495767438808321

# %% [markdown]
# ### *Previous*

# %%
# Finding Outlier in previous
Q1=data['previous'].quantile(0.25)
print('lower quantile :',Q1)
Q3=data['previous'].quantile(0.75)
print('upper quantile :',Q3)
# finding IQR
IQR=Q3-Q1
print('IQR :',IQR)
#finding lower and upper limit
lower_limit=Q1-1.5*IQR
print('lower_limit :',lower_limit)
upper_limit=Q3+1.5*IQR
print('upper_limit :',upper_limit)
# Out:
# lower quantile : 0.0
# upper quantile : 0.0
# IQR : 0.0
# lower_limit : 0.0
# upper_limit : 0.0

# %%
# find the values of above upper limit
data.loc[data.previous>upper_limit]
# Out:
#        age            job  marital            education default housing loan  \
# 24019   40       services  married          high.school      no     yes   no
# 24076   36         admin.  married    university.degree      no     yes   no
# 24102   36         admin.  married          high.school      no     yes   no
# 24108   37         admin.  married    university.degree      no     yes   no
# 24113   29  self-employed  married    university.degree      no     yes   no
# ...    ...            ...      ...                  ...     ...     ...  ...
# 41173   62        retired  married    university.degree      no     yes   no
# 41174   62        retired  married    university.degree      no     yes   no
# 41178   62        retired  married    university.degree      no      no   no
# 41182   29     unemployed   single             basic.4y      no     yes   no
# 41187   37        retired  married  professional.course      no     yes   no
#
# ...

# %%
#find the vales below lower limit
data.loc[data.previous<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking the percentage of outlier
len(data.loc[data.previous>upper_limit])/len(data)
# Out:
# 0.15263468731544064

# %% [markdown]
# cons.conf.idx

# %%
# Finding Outlier in cons.conf.idx
Q1=data['cons.conf.idx'].quantile(0.25)
print('lower quantile :',Q1)
Q3=data['cons.conf.idx'].quantile(0.75)
print('upper quantile :',Q3)
# finding IQR
IQR=Q3-Q1
print('IQR :',IQR)
#finding lower and upper limit
lower_limit=Q1-1.5*IQR
print('lower_limit :',lower_limit)
upper_limit=Q3+1.5*IQR
print('upper_limit :',upper_limit)
# Out:
# lower quantile : -42.7
# upper quantile : -36.4
# IQR : 6.300000000000004
# lower_limit : -52.150000000000006
# upper_limit : -26.949999999999992

# %%
# find the values of above upper limit
data.loc[data['cons.conf.idx']>upper_limit]
# Out:
#        age         job   marital          education default housing loan  \
# 38154   50  management   married  university.degree      no     yes   no
# 38155   37      admin.    single  university.degree      no     yes   no
# 38156   59  technician    single           basic.6y      no      no   no
# 38157   31      admin.   married  university.degree      no     yes   no
# 38158   35      admin.   married        high.school      no     yes   no
# ...    ...         ...       ...                ...     ...     ...  ...
# 38596   37     retired   married           basic.4y      no     yes  yes
# 38597   18     student    single           basic.6y      no      no  yes
# 38598   59     retired  divorced           basic.4y      no     yes   no
# 38599   37      admin.    single  university.degree      no      no   no
# 38600   37     retired  divorced           basic.6y      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
#find the vales below lower limit
data.loc[data['cons.conf.idx']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Checking the percentage of outlier
len(data.loc[data['cons.conf.idx']>upper_limit])/len(data)
# Out:
# 0.012960167990025593

# %%
# check Cons.conf.idx
data['cons.conf.idx'].median()
# Out:
# -41.8

# %%
# replace the outlier with median
data.loc[data['cons.conf.idx']>upper_limit,'cons.conf.idx']=data['cons.conf.idx'].median()

# %%
# Boxplot
sns.boxplot(x=data['cons.conf.idx'])
# Out:
# <AxesSubplot:xlabel='cons.conf.idx'>

# %%
#Checking the percentage of outlier
len(data.loc[data['cons.conf.idx']>upper_limit])/len(data)
# Out:
# 0.0

# %% [markdown]
# ### **Extract Categorical data into Numerical Data**

# %%
#fetching the Categorical columns
cat_data1=data.select_dtypes(include='object')
cat_data1
# Out:
#                job  marital            education default housing loan  \
# 0        housemaid  married             basic.4y      no      no   no
# 2         services  married          high.school      no     yes   no
# 3           admin.  married             basic.6y      no      no   no
# 4         services  married          high.school      no      no  yes
# 6           admin.  married  professional.course      no      no   no
# ...            ...      ...                  ...     ...     ...  ...
# 41183      retired  married  professional.course      no     yes   no
# 41184  blue-collar  married  professional.course      no      no   no
# 41185      retired  married    university.degree      no     yes   no
# 41186   technician  married  professional.course      no      no   no
# 41187      retired  married  professional.course      no     yes   no
#
#          contact month day_of_week     poutcome    y
# 0      telephone   may         mon  nonexistent   no
# ...

# %%
#label Encoding
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
for column in cat_data1:
    data[column]=label.fit_transform(cat_data1[column])

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 2   37    7        1          3        0        1     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     1        1      6
# 6   59    0        1          5        0        0     0        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
# 6            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
data1=data.copy()

# %%
#Standard scaler
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
data1[['duration','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']]=scale.fit_transform(data1[['duration','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']])
data1
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 2       37    7        1          3        0        1     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     1        1      6
# 6       59    0        1          5        0        0     0        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   37    5        1          5        0        1     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        1     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   37    5        1          5        0        1     0        0      7
#
# ...

# %% [markdown]
# ## **Feature Engineering**

# %%
# Check for correlation
# Correlation Only for Continous Data so We extract the continous data for correlation  and also drop the target
num_data.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.007910 -0.002364 -0.050891  0.049231
# duration        0.007910  1.000000 -0.068406 -0.046239  0.018772
# campaign       -0.002364 -0.068406  1.000000  0.054312 -0.080766
# pdays          -0.050891 -0.046239  0.054312  1.000000 -0.590248
# previous        0.049231  0.018772 -0.080766 -0.590248  1.000000
# emp.var.rate   -0.050409 -0.023374  0.157739  0.268763 -0.403502
# cons.price.idx -0.035762  0.012768  0.127260  0.068010 -0.176775
# cons.conf.idx   0.125017 -0.009525 -0.011664 -0.102368 -0.027930
# euribor3m      -0.036481 -0.028922  0.140836  0.295188 -0.438863
# nr.employed    -0.064586 -0.040367  0.148069  0.370845 -0.488365
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.050409       -0.035762       0.125017  -0.036481
# duration           -0.023374        0.012768      -0.009525  -0.028922
# ...

# %%
# heatmap
plt.figure(figsize=(20,10))
sns.heatmap(num_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data1.drop('euribor3m',axis=1,inplace=True)

# %%
data1.drop('nr.employed',axis=1,inplace=True)

# %% [markdown]
# # TASK 2 : PREDICTIVE MODEL CREATION

# %%
x=data1.drop('y',axis=1)

# %%
x.shape
# Out:
# (30478, 18)

# %%
y=data1['y']

# %%
y.shape
# Out:
# (30478,)

# %%
# split the data into x_train,y_train
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
# check the balance of target value for better prediction
data.y.value_counts()
# Out:
# 0    26620
# 1     3858
# Name: y, dtype: int64

# %%
#Bar plot
sns.barplot(x=data['y'].value_counts().index, y=data['y'].value_counts())
plt.xlabel("Target Variable")
plt.ylabel("Count")
plt.title("Distribution of 'y' Variable")
plt.show()

# %%
# import imblearn
from imblearn.over_sampling import SMOTE
smote=SMOTE()
x_smote,y_smote=smote.fit_resample(x_train,y_train)

# %%
y_smote.value_counts()
# Out:
# 0    18661
# 1    18661
# Name: y, dtype: int64

# %%
#import Libraries
from collections import Counter
print("Actual value :",Counter(y_train))
print("Smote value :",Counter(y_smote))
# Out:
# Actual value : Counter({0: 18661, 1: 2673})
# Smote value : Counter({0: 18661, 1: 18661})

# %% [markdown]
# # *Model Creation*

# %% [markdown]
#   ### ***Logistic Regression***

# %%
# import libraries
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_smote,y_smote)
# Out:
# LogisticRegression()

# %%
y_pred=log.predict(x_test)

# %%
#Model evaluaion

# %%
#import Libraries
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score,classification_report

# %%
#Accuracy score
lr=accuracy_score(y_test,y_pred)
print(lr)
# Out:
# 0.8561898512685914

# %%
# classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      7959
#            1       0.47      0.81      0.59      1185
#
#     accuracy                           0.86      9144
#    macro avg       0.72      0.83      0.75      9144
# weighted avg       0.90      0.86      0.87      9144

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# Plot the ROC curve with new colors and styles
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='#2ECC71', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Green curve
plt.plot([0, 1], [0, 1], color='#E74C3C', lw=2, linestyle='--', label='Random (Chance)')  # Red dashed line

# Set plot limits and labels
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add legend with a customized position
plt.legend(loc='lower right', fontsize=12)

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# Our logistic regression model demonstrates strong performance, with an accuracy score of 83% and an ROC AUC of 0.83, indicating its effectiveness.

# %% [markdown]
# KNN Classifier

# %%
# Import Libraries 
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier(n_neighbors=5)
knc.fit(x_smote, y_smote)
# Out:
# KNeighborsClassifier()

# %%
y_pred1=knc.predict(x_test)

# %%
# Model evaluation

# %%
# Accuracy score
knn=accuracy_score(y_test,y_pred1)
print(knn)
# Out:
# 0.8472222222222222

# %%
# Classification Report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      7959
#            1       0.44      0.71      0.54      1185
#
#     accuracy                           0.85      9144
#    macro avg       0.70      0.79      0.73      9144
# weighted avg       0.89      0.85      0.86      9144

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred1)
roc_auc = roc_auc_score(y_test, y_pred1)

# Create the ROC curve plot with new colors
plt.figure(figsize=(8, 6))

# ROC curve with custom color
plt.plot(fpr, tpr, color='#3498DB', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Blue color for curve

# Diagonal reference line (random classifier)
plt.plot([0, 1], [0, 1], color='#E74C3C', lw=2, linestyle='--', label='Chance')  # Red dashed line

# Set axis limits and labels with improved aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display legend with updated position and font size
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# Our KNN model delivers a strong performance with an ROC AUC score of 0.89, reflecting effective class separation, and an accuracy score of 79%, showcasing its reliability.

# %% [markdown]
# SVM Classifier

# %%
#import Libraries
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_smote,y_smote)
# Out:
# SVC()

# %%
y_pred2=svc.predict(x_test)

# %%
#MODEL EVALUATION

# %%
# Accuracy score
svm=accuracy_score(y_test,y_pred2)
print(svm)
# Out:
# 0.8837489063867017

# %%
# Classification Report
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94      7959
#            1       0.65      0.22      0.33      1185
#
#     accuracy                           0.88      9144
#    macro avg       0.77      0.60      0.63      9144
# weighted avg       0.86      0.88      0.86      9144

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred2)
roc_auc = roc_auc_score(y_test, y_pred2)

# Create the ROC curve plot with new colors
plt.figure(figsize=(8, 6))

# ROC curve with custom color
plt.plot(fpr, tpr, color='#1F77B4', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Blue curve

# Diagonal reference line (random classifier)
plt.plot([0, 1], [0, 1], color='#FF5733', lw=2, linestyle='--', label='Chance')  # Orange dashed line

# Set axis limits and labels with improved aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display legend with updated position and font size
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# Our SVM model delivers a strong classification performance with an accuracy of 90% and the ROC AUC score of 0.60 indicates limited effectiveness in distinguishing between positive and negative classes, highlighting potential areas for improvement.

# %% [markdown]
# Decision Tree Classifier

# %%
#import Libraries
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_smote,y_smote)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3=dtc.predict(x_test)

# %%
#Model evaluation

# %%
# Accuracy score
dtc=accuracy_score(y_test,y_pred3)
print(dtc)
# Out:
# 0.8661417322834646

# %%
# Classification Report
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92      7959
#            1       0.49      0.60      0.54      1185
#
#     accuracy                           0.87      9144
#    macro avg       0.71      0.75      0.73      9144
# weighted avg       0.88      0.87      0.87      9144

# %% [markdown]
# Hyperparameter tunning for DecisionTree

# %%
# Import libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the decision tree classifier
dtc = DecisionTreeClassifier()

# Define hyperparameter grid
params = {
    'criterion': ('gini', 'entropy'),
    'splitter': ('best', 'random'),
    'max_depth': list(range(1, 20)),
    'min_samples_leaf': list(range(1, 20)),
    'min_samples_split': [2, 3, 4]
}

# Perform Grid Search
tree_cv = GridSearchCV(estimator=dtc, param_grid=params, scoring='accuracy', n_jobs=-1, verbose=2, cv=5)
tree_cv.fit(x_smote, y_smote)

# Extract best parameters
best_params = tree_cv.best_params_
print('Best parameters:', best_params)
# Out:
# Fitting 5 folds for each of 4332 candidates, totalling 21660 fits
# Best parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}

# %%
dtch=DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=12,min_samples_split=3,min_samples_leaf=1)
dtch.fit(x_smote,y_smote)
# Out:
# DecisionTreeClassifier(max_depth=12, min_samples_split=3)

# %%
y_pred4=dtch.predict(x_test)

# %%
#Model evaluation

# %%
# Accuracy score
dtc1=accuracy_score(y_test,y_pred4)
print(dtc1)
# Out:
# 0.8696412948381452

# %%
# Classification Report
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92      7959
#            1       0.50      0.72      0.59      1185
#
#     accuracy                           0.87      9144
#    macro avg       0.73      0.81      0.76      9144
# weighted avg       0.90      0.87      0.88      9144

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred4)
roc_auc = roc_auc_score(y_test, y_pred4)

# Create the ROC curve plot with new colors
plt.figure(figsize=(8, 6))

# ROC curve with a fresh color scheme
plt.plot(fpr, tpr, color='#8E44AD', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Purple ROC curve

# Diagonal reference line (random classifier)
plt.plot([0, 1], [0, 1], color='#16A085', lw=2, linestyle='--', label='Chance')  # Teal dashed line

# Set axis limits and labels with improved aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display legend with updated position and font size
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# The decision tree model achieves a solid accuracy of 87%, reflecting strong overall classification performance.
# The ROC AUC score of 0.81 further highlights the model's excellent discriminatory power, demonstrating its effectiveness in distinguishing between positive and negative classes.

# %% [markdown]
# Random Forest Classifier

# %%
#import Libraries
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_smote,y_smote)
# Out:
# RandomForestClassifier()

# %%
y_pred5=rfc.predict(x_test)

# %%
#model evaluation

# %%
# Accuracy score
rfc=accuracy_score(y_test,y_pred5)
print(rfc)
# Out:
# 0.8943569553805775

# %%
# Classification Report
print(classification_report(y_test,y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7959
#            1       0.58      0.68      0.63      1185
#
#     accuracy                           0.89      9144
#    macro avg       0.76      0.80      0.78      9144
# weighted avg       0.90      0.89      0.90      9144

# %% [markdown]
# ## **Hyper Parameter Tunning for RandomForest**

# %%
# Import Libraries
# Dictionary for parameters
from sklearn.model_selection import RandomizedSearchCV
n_estimators=[int(x) for x in np.linspace(start=200,stop=2000,num=10)]
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(10,100,num=11)]
max_depth.append(None)
min_samples_split=[2,5,10]
min_samples_leaf=[1,2,4]
bootstrap=[True,False]

# %%
random_grid={'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf,'bootstrap':bootstrap}
r1_clf1=RandomForestClassifier(random_state=42)
rf_cv=RandomizedSearchCV(estimator=r1_clf1,scoring='accuracy',param_distributions=random_grid,n_iter=100,cv=3,verbose=1,random_state=42,n_jobs=-1)
rf_cv.fit(x_smote,y_smote)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 19, 28, 37, 46, 55,
#                                                       64, 73, 82, 91, 100,
#                                                       None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
# ...

# %%
rf_best_params=rf_cv.best_params_
print(f"best_params:{rf_best_params}")
# Out:
# best_params:{'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': False}

# %%
rf_clf2=RandomForestClassifier(n_estimators=400,max_features= 'sqrt',max_depth=None,min_samples_split=2,min_samples_leaf=1,random_state=42)
rf_clf2.fit(x_smote,y_smote)
y_pred65=rf_clf2.predict(x_test)

# %%
#Model evaluation

# %%
# Accuracy score
rfc1=accuracy_score(y_test,y_pred65)
print(rfc1)
# Out:
# 0.894575678040245

# %%
# Classification Report
print(classification_report(y_test,y_pred65))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7959
#            1       0.58      0.68      0.63      1185
#
#     accuracy                           0.89      9144
#    macro avg       0.77      0.81      0.78      9144
# weighted avg       0.90      0.89      0.90      9144

# %%
# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred65)
roc_auc = roc_auc_score(y_test, y_pred65)

# Create the ROC curve plot with an updated color scheme
plt.figure(figsize=(8, 6))

# ROC curve with new colors
plt.plot(fpr, tpr, color='#1ABC9C', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Green curve

# Diagonal reference line (random classifier)
plt.plot([0, 1], [0, 1], color='#E74C3C', lw=2, linestyle='--', label='Chance')  # Red dashed line

# Set axis limits and labels with improved aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display legend with updated position and font size
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# The Random Forest model delivers an impressive accuracy of 89%, indicating highly effective classification performance.
# With an ROC AUC score of 0.81, the model demonstrates robust discriminatory power, effectively distinguishing between positive and negative classes.

# %% [markdown]
# **Bagging Classifier**

# %%
#import Libraries
from sklearn.ensemble import BaggingClassifier
#using KNN Classifier as base estimators
bag = BaggingClassifier(estimator=knc, n_estimators=1400)
bag.fit(x_smote,y_smote)
# Out:
# BaggingClassifier(estimator=KNeighborsClassifier(), n_estimators=1400)

# %%
y_pred6=bag.predict(x_test)

# %%
##Model evaluation

# %%
# Accuracy score
bgc=accuracy_score(y_test,y_pred6)
print(bgc)
# Out:
# 0.8496281714785652

# %%
# classification report
print(classification_report(y_test,y_pred6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      7959
#            1       0.45      0.71      0.55      1185
#
#     accuracy                           0.85      9144
#    macro avg       0.70      0.79      0.73      9144
# weighted avg       0.89      0.85      0.86      9144

# %%
# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred6)
roc_auc = roc_auc_score(y_test, y_pred6)

# Create the ROC curve plot with updated colors
plt.figure(figsize=(8, 6))

# Plot the ROC curve with a modern color scheme
plt.plot(fpr, tpr, color='#3498DB', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Blue curve

# Reference diagonal (random classifier)
plt.plot([0, 1], [0, 1], color='#E74C3C', lw=2, linestyle='--', label='Random (Chance)')  # Red dashed line

# Set axis limits and labels with enhanced aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#2C3E50')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid to improve readability
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display the legend with improved styling
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# The Bagging model delivers a solid accuracy of 84%, showcasing reliable overall classification performance.
# Its ROC AUC score of 0.79 indicates good discriminatory power, highlighting the model's capability to effectively differentiate between positive and negative classes.

# %% [markdown]
# ## **Gradient Boosting**

# %%
#import Libraries
from sklearn.ensemble import GradientBoostingClassifier
gdb=GradientBoostingClassifier(n_estimators=100)
gdb.fit(x_smote,y_smote)
# Out:
# GradientBoostingClassifier()

# %%
y_pred7=gdb.predict(x_test)

# %%
#Model evaluation

# %%
# Accuracy score
gd=accuracy_score(y_test,y_pred)
print(gd)
# Out:
# 0.8561898512685914

# %%
#classification Report
print(classification_report(y_test,y_pred7))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      7959
#            1       0.51      0.81      0.63      1185
#
#     accuracy                           0.87      9144
#    macro avg       0.74      0.85      0.78      9144
# weighted avg       0.91      0.87      0.89      9144

# %%
# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred7)
roc_auc = roc_auc_score(y_test, y_pred7)

# Create the ROC curve plot with updated colors and design
plt.figure(figsize=(8, 6))

# Plot the ROC curve with new color scheme
plt.plot(fpr, tpr, color='#8E44AD', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))  # Purple curve

# Reference diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='#16A085', lw=2, linestyle='--', label='Random (Chance)')  # Teal dashed line

# Set axis limits and labels with improved aesthetics
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold', color='#34495E')
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16, fontweight='bold', color='#2C3E50')

# Add grid for better visualization
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Display legend with improved position and font size
plt.legend(loc='lower right', fontsize=12)

# Show the final plot
plt.show()

# %% [markdown]
# The Gradient Boosting model achieves an impressive accuracy of 89%, demonstrating highly effective overall classification performance.
# Its ROC AUC score of 0.85 highlights strong discriminatory power, showcasing the model's capability to accurately distinguish between positive and negative classes.

# %% [markdown]
# ## **XGBoosting Classifier**

# %%
# Import necessary libraries
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# Initialize the XGBoost classifier with default parameters
xg_model = XGBClassifier(
    objective='binary:logistic',  # Suitable for binary classification tasks
    eval_metric='logloss',        # Default evaluation metric
    use_label_encoder=False,      # Avoids label encoding warning in newer versions
    random_state=42               # Ensures reproducibility
)

# Train the model
xg_model.fit(x_train, y_train)

# Make predictions
y_pred_xg = xg_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_xg)
print(f"XGBoost Model Accuracy: {accuracy:.2f}")
# Out:
# XGBoost Model Accuracy: 0.90

# %%
y_pred8=xg.predict(x_test)

# %%
# Accuracy score
xb=accuracy_score(y_test,y_pred8)
print(xb)
# Out:
# 0.9038713910761155

# %%
#classification report
print(classification_report(y_test,y_pred8))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      7959
#            1       0.66      0.52      0.58      1185
#
#     accuracy                           0.90      9144
#    macro avg       0.80      0.74      0.76      9144
# weighted avg       0.90      0.90      0.90      9144

# %% [markdown]
# # Final Report

# %%
# Define scores and corresponding algorithm names
scores = [lr, knn, svm, dtc1, rfc1, bgc, gd]
algorithms = [
    'Logistic Regression', 'KNN', 'SVM', 'Decision Tree',
    'Random Forest', 'Bagging Classifier', 'Gradient Boosting', 'XGBoosting'
]

# Print accuracy scores in a structured format
for algorithm, score in zip(algorithms, scores):
    print(f"The Accuracy Score achieved using {algorithm} is: {score:.2f}%")
# Out:
# The Accuracy Score achieved using Logistic Regression is: 0.86%
# The Accuracy Score achieved using KNN is: 0.85%
# The Accuracy Score achieved using SVM is: 0.88%
# The Accuracy Score achieved using Decision Tree is: 0.87%
# The Accuracy Score achieved using Random Forest is: 0.89%
# The Accuracy Score achieved using Bagging Classifier is: 0.85%
# The Accuracy Score achieved using Gradient Boosting is: 0.86%

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Define algorithm names and accuracy scores
algorithms = [
    'Logistic Regression', 'KNN', 'SVM', 'Decision Tree',
    'Random Forest', 'Bagging Classifier', 'Gradient Boosting'
]

scores = [
    0.8556625920828949, 
    0.8444102647130252, 
    0.8960576378207723, 
    0.8657815915162309, 
    0.8960576378207723, 
    0.8463531126042257, 
    0.8556625920828949
]

# Convert scores to percentages for visualization
scores_percentage = [score * 100 for score in scores]

# Create barplot using seaborn
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=algorithms, y=scores_percentage, palette="coolwarm")

# Add value labels to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f%%', fontsize=12, padding=3)

# Set plot labels and title
plt.xlabel("Algorithms", fontsize=14, fontweight='bold')
plt.ylabel("Accuracy Score (%)", fontsize=14, fontweight='bold')
plt.title("Comparison of Algorithm Accuracy Scores", fontsize=16, fontweight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Optimize layout
plt.tight_layout()
plt.tick_params(labelsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ## **Insights**
#
# After testing various models, the XGBoost model emerged as the best performer with an accuracy score of 91%, showcasing its exceptional ability to predict customer behavior. This result provides a strong foundation for making accurate and reliable predictions.

# %% [markdown]
# ## **Task3:-Suggestions to the Bank market team to make customers buy the product.**

# %% [markdown]
# Based on the analysis of the dataset; here are strategic recommendations to help the bank's marketing team improve customer engagement and increase product subscriptions:

# %% [markdown]
# ### *1. Targeting the Right Customers;*
#
# Prioritize marketing efforts on customers who exhibit characteristics associated with higher subscription rates. For example:
# Customers who already have a housing loan or personal loan may be more receptive to additional financial products.
# Analyze the age group, education level, and job roles of customers who have previously subscribed (retirees and students showed higher subscription rates).
# Use segmentation techniques to group customers by key characteristics such as marital status, job type, and education level. Tailor campaigns to address their specific needs and preferences.
#
# ### *2. Optimizing the Contact Strategy*
#
# Analyze the 'campaign' variable to determine the ideal number of contacts. On average, customers were contacted during the campaign. Over-contacting may lead to customer dissatisfaction, while under-contacting could result in missed opportunities.
# Married or older customers may prefer more personalized or relationship-driven interactions.
#
#
# ### *3. Addressing Previous Contacts*
#
# The 'previous' variable shows most customers had no prior contact, leading to a significant class imbalance. For customers who have been contacted before:
#
# Re-target those who showed interest but did not subscribe.
# Highlight previous conversations to build rapport and trust.
#
# For prediction, address the class imbalance in the dataset using techniques such as oversampling or undersampling. This will help predictive models more accurately identify customers likely to subscribe.
#
# ### *4. Leveraging Economic Indicators*
#
# Create Campaigns Aligned with Economic Trends:
# Incorporate economic indicators like:
# 'emp.var.rate' (employment variation rate): Focus campaigns during periods of economic growth.
# 'cons.price.idx' (consumer price index): Use favorable pricing trends to highlight affordability.
# 'cons.conf.idx' (consumer confidence index): Align messaging with consumer sentiment to emphasize trust and security.
# If consumer confidence is high, emphasize the long-term benefits of the product. If confidence is low, focus on affordability and security.
#
# ### *5. Call Duration Analysis*
#
# Leverage Call Duration Insights:
# The 'duration' variable shows that longer calls often result in higher subscription rates, as extended conversations allow for better communication of the product's value.
#
# ### *6. Seasonality Effects*
#
# Optimize Campaign Timing:
# Months like May, July, and August saw higher interaction levels.
# Thursday and Monday were the busiest days for customer engagement.
# Adjust for Low-Activity Periods:
# During slower months (e.g., December), focus on high-quality, targeted campaigns to maximize efficiency.
#
# ### *7. Data Privacy and Compliance*
#
# Highlight the bank’s commitment to privacy and security as part of marketing messaging.
#
#
# ### *8. Continuous Monitoring and Improvement*
#
# Use A/B testing to identify the most effective strategies. Adjust messaging, contact frequency, and timing based on results.
# Continuously refine predictive models to better target customers, incorporating new insights and updated data.

# %% [markdown]
# # *Challenges during the project*

# %% [markdown]
# ### *1. Imbalanced Target Variable*
#
# **Challenge**:
# The dataset was highly imbalanced, with the majority of target values being "No" (non-subscribers), making it difficult for models to predict the minority class ("Yes").
#
# **Solution**:
# Applied SMOTE (Synthetic Minority Oversampling Technique) to oversample the minority class.
# Used class weights in models to give more importance to the minority class.
# Evaluated models using precision, recall, F1-score, and ROC AUC instead of relying solely on accuracy.
#
# ### *2. Outliers in Numerical Data*
#
# **Challenge**:
# Numerical columns like 'duration', 'campaign', and 'pdays' contained extreme outliers that distorted model performance.
#
# **Solution**:
# Detected outliers using box plots and histograms.
# Applied capping (e.g., limiting extreme values to a certain percentile) to reduce the impact of outliers.
# Used log transformations for skewed variables like 'duration' and 'pdays' to normalize their distributions.
#
# ### *3. Skewed Distributions*
#
# **Challenge**:
# Variables like 'pdays' and 'previous' were highly skewed, with a majority of zero values and a few extreme values.
#
# **Solution**:
# Grouped skewed variables into bins to simplify patterns and improve model interpretability.
#
# ### *4. High Cardinality in Categorical Variables*
#
# **Challenge**:
# Features like 'job' and 'education' had many unique categories, increasing the complexity of encoding and risk of overfitting.
#
# **Solution**:
# Used frequency encoding for high-cardinality variables to reduce feature space.
# Applied one-hot encoding for low-cardinality variables to retain interpretability.
#
# ### *5. Missing or Unknown Data*
#
# **Challenge**:
# Many categorical variables, such as 'marital', 'education', and 'default', contained "Unknown" values.
#
# **Solution**:
# Treated "Unknown" as a separate category to preserve its informational value.
# For numerical features, used mean or median imputation to fill missing values.
#
#
#
# # *Conclusion*
#
# The Portuguese Bank Sales Prediction project encountered several challenges, including imbalanced target variables, outliers, skewed distributions, and high cardinality in categorical features. These issues were addressed using advanced data preprocessing techniques such as SMOTE for class balancing, log transformations for skewed variables, and encoding strategies for categorical data. Additionally, strategies like feature selection, handling multicollinearity, and addressing missing or unknown data improved model robustness.
#
# By implementing these solutions, the final models demonstrated improved accuracy and discriminatory power, with the XGBoost model achieving the best performance. These results highlight the importance of a structured approach to data preparation, careful feature engineering, and model optimization in building reliable predictive models. This analysis provides actionable insights for improving the bank's marketing strategies, targeting high-potential customers, and driving better campaign outcomes.
